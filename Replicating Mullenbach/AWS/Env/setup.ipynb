# %%
import os
from model import GenerateModel

# %%
# logger.debug("Harmless debug Message")
# logger.info("Just an information")
# logger.warning("Its a Warning")
# logger.error("Did you try to divide by zero")
# logger.critical("Internet is down")

# %%
# Validate file paths and try writing
s3_bucket = \
"/Users/drew/Documents/GitHub/FL-with-MIMIC/Replicating Mullenbach/AWS/S3_Bucket"
assert(os.path.isdir(s3_bucket))

# %%
# !python3 train.py \
--s3_path "/Users/drew/Documents/GitHub/FL-with-MIMIC/Replicating Mullenbach/AWS/S3_Bucket" \
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/Resources/Python.app/Contents/MacOS/Python: can't open file '/Users/drew/Documents/GitHub/FL-with-MIMIC/Replicating Mullenbach/train.py': [Errno 2] No such file or directory

# %%
import numpy as np
import torch

# %%
X_test  = np.load("X_test.npy"  )
Y_test  = np.load("Y_test.npy"  )
X_train = np.load("X_train.npy" )
Y_train = np.load("Y_train.npy" )

# %%
X_test  = torch.from_numpy(X_test).type(torch.long)
Y_test  = torch.from_numpy(Y_test).type(torch.float64)
X_train = torch.from_numpy(X_train).type(torch.long)
Y_train = torch.from_numpy(Y_train).type(torch.float64)

# %%
# data_path = "/Users/drew/Documents/GitHub/FL-with-MIMIC/Replicating Mullenbach/AWS/S3_Bucket/Data"
# torch.save(Y_test,f = os.path.join(data_path,'Y_test.pt'))
