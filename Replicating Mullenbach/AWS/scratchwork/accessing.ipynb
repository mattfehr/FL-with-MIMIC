# %%
import boto3

s3 = boto3.client('s3')
bucket_name = 'sagemaker-us-east-1-762568382963'
file_key = 'X_test.npy'

# %%
s3.list_buckets()
# Out:
# {'ResponseMetadata': {'RequestId': '91AHF4HH92AEX828',
#   'HostId': 'd1CepcAnjKOym/j6eRQ6jNqXAIhFmfTG/h8nTDDOKpSocfIApG7Z/DW1XCUr7yCI1+maPpwkONpazqHH/2mnAe/mHCEWTmWC',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'd1CepcAnjKOym/j6eRQ6jNqXAIhFmfTG/h8nTDDOKpSocfIApG7Z/DW1XCUr7yCI1+maPpwkONpazqHH/2mnAe/mHCEWTmWC',
#    'x-amz-request-id': '91AHF4HH92AEX828',
#    'date': 'Mon, 01 Sep 2025 20:52:45 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'sagemaker-us-east-1-762568382963',
#    'CreationDate': datetime.datetime(2025, 8, 29, 18, 39, 14, tzinfo=tzlocal())}],
#  'Owner': {'ID': '048bd119a5df2bce5c1c47bf218683501d6ec58ba7f54407d866e2ebc5987954'}}

# %%
s3.download_file(bucket_name, file_key,"data/data.npy")

# %%
s3.upload_file("tmp.txt",'sagemaker-us-east-1-762568382963',"Data/tmp.txt")

# %%
# np.load(os.path.join(bucket_name,file_key))
