# %%
import matplotlib.pyplot as plt
import polars  as pl
import seaborn as sns
import numpy   as np
import os

default_path = os.getcwd()
default_path
# Out:
# '/Users/avaldivia/Documents/GitHub/Split-Learning/Exploratory'

# %%
#os.chdir('..')

# %%
df = (
    pl.scan_csv(source = 'ADMISSIONS.csv.gz', low_memory = True)
    .collect(streaming=True)
)

# %%
distribution = df['SUBJECT_ID'].value_counts().filter(pl.col('count') == 5)

# %%
freq = df['SUBJECT_ID'].value_counts()['count']
freq
# Out:
# shape: (46_520,)
# Series: 'count' [u32]
# [
# 	1
# 	1
# 	1
# 	1
# 	1
# 	…
# 	3
# 	2
# 	2
# 	1
# 	2
# ]

# %%
freq = freq.rename(name = 'freq')

# %%
plt.bar(x = freq.value_counts(sort=True)['freq'], height=freq.value_counts(sort=True)['count'])
plt.xlim(0,40)
plt.ylim(0,80)
plt.show()

# %%
df.head()
# Out:
# shape: (5, 19)
# ┌────────┬────────────┬─────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ ROW_ID ┆ SUBJECT_ID ┆ HADM_ID ┆ ADMITTIME  ┆ … ┆ EDOUTTIME  ┆ DIAGNOSIS  ┆ HOSPITAL_ ┆ HAS_CHART │
# │ ---    ┆ ---        ┆ ---     ┆ ---        ┆   ┆ ---        ┆ ---        ┆ EXPIRE_FL ┆ EVENTS_DA │
# │ i64    ┆ i64        ┆ i64     ┆ str        ┆   ┆ str        ┆ str        ┆ AG        ┆ TA        │
# │        ┆            ┆         ┆            ┆   ┆            ┆            ┆ ---       ┆ ---       │
# │        ┆            ┆         ┆            ┆   ┆            ┆            ┆ i64       ┆ i64       │
# ╞════════╪════════════╪═════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 21     ┆ 22         ┆ 165315  ┆ 2196-04-09 ┆ … ┆ 2196-04-09 ┆ BENZODIAZE ┆ 0         ┆ 1         │
# │        ┆            ┆         ┆ 12:26:00   ┆   ┆ 13:24:00   ┆ PINE       ┆           ┆           │
# ...
